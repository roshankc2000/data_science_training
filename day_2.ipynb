# %% [markdown]
# # day_2

# %% [markdown]
# # boooooooring lecture again

# %% [markdown]
# ## creating virtual environment

# %% [markdown]
# ### using conda

# %% [markdown]
# ![image.png](attachment:d69459fb-cdc9-47fc-96eb-d087122339c8.png)

# %% [markdown]
# ![image.png](attachment:33b452ab-abb7-4b89-9387-f8b9e1e8a36e.png)

# %% [markdown]
# ## to check list of environments

# %% [markdown]
# ![image.png](attachment:309eb41c-b8ba-4b9a-abc7-ffeb0944d5a1.png)
